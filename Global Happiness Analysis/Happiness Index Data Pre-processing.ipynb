# %%
import pandas as pd
import numpy as np
pd.set_option('max_column',None)

# %%
till_2018=pd.read_excel(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Project 1\till_2018.xlsx')
df_2019=pd.read_excel(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Project 1\2019_HI_Data.xlsx')
df_2020=pd.read_excel(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Project 1\2020_Happiness_IndexData.xls')
df_2021=pd.read_excel(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Project 1\2021_Happiness_IndexData.xls')

# %%
till_2018.head()
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
hi_2018=till_2018[['Year','Country name','Life Ladder','Log GDP per capita','Social support','Healthy life expectancy at birth','Freedom to make life choices','Generosity','Perceptions of corruption']]

# %%
hi_2018.rename(columns={'Country name':'Country','Life Ladder':'Happiness Score'},inplace=True)
hi_2018.head()
# Out:
# C:\Users\rutuj\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    Year      Country  Happiness Score  Log GDP per capita  Social support  \
# 0  2008  Afghanistan         3.723590            7.168690        0.450662
# 1  2009  Afghanistan         4.401778            7.333790        0.552308
# 2  2010  Afghanistan         4.758381            7.386629        0.539075
# 3  2011  Afghanistan         3.831719            7.415019        0.521104
# 4  2012  Afghanistan         3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# ...

# %%
df_2019['Year']=pd.to_datetime(2019,format='%Y').year

# %%
hi_2019=df_2019[['Year','Country','Happiness score','Explained by: GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption']]
hi_2019.rename(columns={'Happiness score':'Happiness Score','Explained by: GDP per capita':'Log GDP per capita','Explained by: Social support':'Social support','Explained by: Healthy life expectancy':'Healthy life expectancy at birth','Explained by: Freedom to make life choices':'Freedom to make life choices','Explained by: Generosity':'Generosity','Explained by: Perceptions of corruption':'Perceptions of corruption'},inplace=True)
hi_2019.head()
# Out:
# C:\Users\rutuj\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    Year      Country  Happiness Score  Log GDP per capita  Social support  \
# 0  2019      Finland           7.7689            1.340243        1.587276
# 1  2019      Denmark           7.6001            1.383439        1.572595
# 2  2019       Norway           7.5539            1.487767        1.581548
# 3  2019      Iceland           7.4936            1.380163        1.623651
# 4  2019  Netherlands           7.4876            1.396020        1.521903
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                          0.986145                      0.595895    0.152708
# ...

# %%
#hi_2019=df_2019[['Year','Country','Happiness score','Explained by: GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption']]
df_2020['Year']=pd.to_datetime(2020,format='%Y').year
hi_2020=df_2020[['Year','Country name','Ladder score','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']]
hi_2020.rename(columns={'Country name':'Country','Ladder score':'Happiness Score','Logged GDP per capita':'Log GDP per capita','Healthy life expectancy':'Healthy life expectancy at birth'},inplace=True)
hi_2020.head()
# Out:
# C:\Users\rutuj\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    Year      Country  Happiness Score  Log GDP per capita  Social support  \
# 0  2020      Finland           7.8087           10.639267        0.954330
# 1  2020      Denmark           7.6456           10.774001        0.955991
# 2  2020  Switzerland           7.5599           10.979933        0.942847
# 3  2020      Iceland           7.5045           10.772559        0.974670
# 4  2020       Norway           7.4880           11.087804        0.952487
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         71.900826                      0.949172   -0.059482
# ...

# %%
df_2021['Year']=pd.to_datetime(2021,format='%Y').year
hi_2021=df_2021[['Year','Country name','Ladder score','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']]
hi_2021.rename(columns={'Country name':'Country','Ladder score':'Happiness Score','Logged GDP per capita':'Log GDP per capita','Healthy life expectancy':'Healthy life expectancy at birth'},inplace=True)
# Out:
# C:\Users\rutuj\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
hi_2021.head()
# Out:
#    Year      Country  Happiness Score  Log GDP per capita  Social support  \
# 0  2021      Finland           7.8421           10.775202        0.953603
# 1  2021      Denmark           7.6195           10.933176        0.954410
# 2  2021  Switzerland           7.5715           11.117368        0.941742
# 3  2021      Iceland           7.5539           10.877768        0.982938
# 4  2021  Netherlands           7.4640           10.931812        0.941601
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         72.000000                      0.949268   -0.097760
# 1                         72.699753                      0.945639    0.030109
# 2                         74.400101                      0.918788    0.024629
# 3                         73.000000                      0.955123    0.160274
# 4                         72.400116                      0.913116    0.175404
#
#    Perceptions of corruption
# ...

# %%
happiness_score=pd.concat([hi_2018,hi_2019,hi_2020,hi_2021])

# %%
happiness_score[happiness_score['Year']==2021]
# Out:
#      Year      Country  Happiness Score  Log GDP per capita  Social support  \
# 0    2021      Finland           7.8421           10.775202        0.953603
# 1    2021      Denmark           7.6195           10.933176        0.954410
# 2    2021  Switzerland           7.5715           11.117368        0.941742
# 3    2021      Iceland           7.5539           10.877768        0.982938
# 4    2021  Netherlands           7.4640           10.931812        0.941601
# ..    ...          ...              ...                 ...             ...
# 144  2021      Lesotho           3.5118            7.925777        0.786871
# 145  2021     Botswana           3.4665            9.781536        0.784171
# 146  2021       Rwanda           3.4147            7.676118        0.552339
# 147  2021     Zimbabwe           3.1448            7.942595        0.750470
# 148  2021  Afghanistan           2.5229            7.694710        0.462596
#
# ...

# %%
happiness_score.to_csv(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Project 1\happiness_score.csv')

# %%
global_hi=happiness_score.groupby(['Year'],as_index=False)['Happiness Score'].mean()

# %%
top_10_data1=happiness_score.sort_values(by=['Happiness Score'],ascending=False)

# %%
top_10_data1
# Out:
#       Year                   Country  Happiness Score  Log GDP per capita  \
# 397   2005                   Denmark         8.018934           10.704770
# 399   2008                   Denmark         7.970892           10.733475
# 495   2018                   Finland         7.858107           10.636060
# 0     2021                   Finland         7.842100           10.775202
# 398   2007                   Denmark         7.834233           10.744484
# ...    ...                       ...              ...                 ...
# 274   2016  Central African Republic         2.693061            6.465948
# 1458  2013                     Syria         2.687553            8.307246
# 9     2017               Afghanistan         2.661718            7.497755
# 152   2020               Afghanistan         2.566900            7.462861
# 148   2021               Afghanistan         2.522900            7.694710
#
#       Social support  Healthy life expectancy at birth  \
# ...

# %%
top_10_data=happiness_score.sort_values(by=['Year','Happiness Score'],ascending=False)

# %%
top_10_data[['Year','Happiness Score']].value_counts()
# Out:
# Year  Happiness Score
# 2005  4.718734           1
# 2017  4.078620           1
#       4.441306           1
#       4.424491           1
#       4.360805           1
#                         ..
# 2012  3.550610           1
#       3.333048           1
#       3.193469           1
#       3.164491           1
# 2021  7.842100           1
# Length: 2162, dtype: int64

# %%
top_10_data.to_csv(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Project 1\top_10_data_1.csv')

# %%
df_2020.groupby('Regional indicator')['Ladder score'].mean()
# Out:
# Regional indicator
# Central and Eastern Europe            5.883818
# Commonwealth of Independent States    5.358342
# East Asia                             5.714850
# Latin America and Caribbean           5.981786
# Middle East and North Africa          5.227159
# North America and ANZ                 7.173525
# South Asia                            4.475443
# Southeast Asia                        5.383367
# Sub-Saharan Africa                    4.383495
# Western Europe                        6.899219
# Name: Ladder score, dtype: float64

# %%
global_hi
# Out:
#     Year  Happiness Score
# 0   2005         6.446164
# 1   2006         5.196935
# 2   2007         5.418291
# 3   2008         5.418554
# 4   2009         5.457640
# 5   2010         5.496782
# 6   2011         5.424088
# 7   2012         5.443751
# 8   2013         5.394568
# 9   2014         5.389023
# 10  2015         5.404037
# 11  2016         5.399414
# 12  2017         5.460421
# 13  2018         5.502134
# 14  2019         5.407081
# 15  2020         5.473240
# 16  2021         5.532832
