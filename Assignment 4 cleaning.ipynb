# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Assignment\Assignment 4\Labor Force Participation Rate.csv')

# %%
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 1  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 2  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 3  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 4  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  65.762931  65.570922  65.654496
# ...

# %%
df1=df.dropna(subset=['1990'])

# %%
df1.shape
# Out:
# (235, 65)

# %%
df1.head()
# Out:
#                   Country Name Country Code  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
# 5                      Albania          ALB
#
#                                       Indicator Name     Indicator Code  1960  \
# 1  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 2  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 3  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 4  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 5  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 1   NaN   NaN   NaN   NaN   NaN  ...  65.762931  65.570922  65.654496
# 2   NaN   NaN   NaN   NaN   NaN  ...  15.454000  15.879000  16.794001
# ...

# %%
df2=df.dropna(subset=['2019'])

# %%
df2.shape
# Out:
# (235, 65)

# %%
df1.to_csv(r'C:\Users\rutuj\OneDrive\Documents\Northeastern University MS in Data Analytics Engineering\5. Computation & Visualization\Assignment\Assignment 4\df_1990_2010.csv')
